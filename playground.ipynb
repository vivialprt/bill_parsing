# %%
import numpy as np
import cv2
import os
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
IM_DIR = 'images'

# %%
im_name = os.listdir(IM_DIR)[0]
im_fullname = os.path.join(IM_DIR, im_name)
im = cv2.imread(im_fullname, cv2.IMREAD_GRAYSCALE)
shape = im.shape

# %%
def imshow(im, size=(6, 8)):
    plt.figure(figsize=size)
    plt.imshow(im, cmap='gray')

# %%
imshow(im)

# %%
plt.hist(resized_im.reshape((1, -1))[0], bins=20)
# Out:
# (array([  231.,   518.,  2427.,  6433.,  8881.,  8713.,  8234.,  5838.,
#          5149.,  4141.,  4546.,  4527.,  6254.,  9550., 24436., 20887.,
#         28318., 52923., 44595.,  2231.]),
#  array([ 10. ,  20.5,  31. ,  41.5,  52. ,  62.5,  73. ,  83.5,  94. ,
#         104.5, 115. , 125.5, 136. , 146.5, 157. , 167.5, 178. , 188.5,
#         199. , 209.5, 220. ]),
#  <a list of 20 Patch objects>)

# %%
new_size = int(shape[1] / 8), int(shape[0] / 8)
resized_im = cv2.resize(im, new_size)
imshow(resized_im)

# %%
ret,thr_im = cv2.threshold(resized_im,140,1,cv2.THRESH_BINARY)
imshow(thr_im)

# %%
area = sum(thr_im.reshape((1, -1))[0])
# Out:
# 186543
